# %%
# !pip install -q xlrd
import pandas as pd

# %%
from google.colab import data_table

data_table.enable_dataframe_formatter()

#URL = "https://mysidc.statistics.gov.my/indikator/downloadfile.php?ddd=xls|<code_no>"
URL = "https://mysidc.statistics.gov.my/indikator/downloadfile.php?ddd=xls|10681" #https://mysidc.statistics.gov.my/

data = pd.read_excel(URL)
data
# Out:
#      Year  Gross Capital Stock (RM Million)  Net Capital Stock (RM Million)  \
# 0    2000                      1.200298e+06                    7.644990e+05
# 1    2001                      1.275723e+06                    8.014026e+05
# 2    2002                      1.338315e+06                    8.350968e+05
# 3    2003                      1.462813e+06                    9.105287e+05
# 4    2004                      1.535403e+06                    9.529039e+05
# 5    2005                      1.660826e+06                    1.072947e+06
# 6    2006                      1.798803e+06                    1.164558e+06
# 7    2007                      1.975868e+06                    1.284242e+06
# 8    2008                      2.134187e+06                    1.382794e+06
# 9    2009                      2.351309e+06                    1.517621e+06
# 10   2010                      2.667944e+06                    1.706549e+06
# ...

# %%
URL = "https://www.data.gov.my/data/dataset/9e3cb0e7-9549-4507-a6f6-9b11fda895b3/resource/572f7e57-7916-4dc5-8d63-c9ff69e6d23a/download/_202111160323000_1.4.1-inbound-tourism-expenditure-of-visitors-by-products-2000-2020_dataset.csv"

data2 = pd.read_csv(URL)
data2
# Out:
#                                              Products   Year  \
# 0                              Accommodation services   2000
# 1                  Food and beverage serving services   2000
# 2                        Passenger transport services   2000
# 3      Travel agencies and other reservation services   2000
# 4          Cultural, sports and recreational services   2000
# ..                                                ...    ...
# 148    Travel agencies and other reservation services  2020p
# 149        Cultural, sports and recreational services  2020p
# 150                    Retail sale of automotive fuel  2020p
# 151     Country-specific tourism characteristic goods  2020p
# 152  Country-specific tourism characteristic services  2020p
#
#      Value (RM Million)
# 0                5686.0
# 1                3792.8
# 2                2197.9
# 3                 816.9
# 4                 972.5
# ..                  ...
# 148               582.5
# 149               395.1
# ...

# %%
# !pip install nbconvert
jupyter nbconvert --to html notebook.ipynb
